# %% [markdown]
# # AUTHORS
#
# - **Mathieu Breier**
#   *BSE DSDM 2023-2024*
#   Email: [mathieu.breier@bse.eu](mailto:mathieu.breier@bse.eu)
#
# - **Guillem Mirabent**
#   *BSE DSDM 2023-2024*
#   Email: [guillem.mirabent@bse.eu](mailto:guillem.mirabent@bse.eu)

# %% [markdown]
# # INDEX

# %% [markdown]
# # LOADS & IMPORTS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay, roc_auc_score, roc_curve, auc, confusion_matrix

import klib as kl 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import plotly.express as px

import seaborn as sns

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from utils_preproc import *

import matplotlib.lines as mlines

from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForSequenceClassification
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/guillemmirabentrubinat/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
bert = "dccuchile/bert-base-spanish-wwm-uncased-finetuned-mldoc"

pipe = pipeline("text-classification", model=bert)

tokenizer = AutoTokenizer.from_pretrained(bert)
model = AutoModelForSequenceClassification.from_pretrained(bert)

# %%
data = pd.read_csv('../Spanish_Parliament_Speeches.csv')
data = kl.clean_column_names(data)
display(data)
# Out:
#                                 text_id  \
# 0      ParlaMint-ES_2022-06-29-CD220629
# 1      ParlaMint-ES_2022-06-29-CD220629
# 2      ParlaMint-ES_2022-06-29-CD220629
# 3      ParlaMint-ES_2022-06-29-CD220629
# 4      ParlaMint-ES_2022-06-29-CD220629
# ...                                 ...
# 32546  ParlaMint-ES_2016-11-15-CD161115
# 32547  ParlaMint-ES_2016-11-15-CD161115
# 32548  ParlaMint-ES_2016-11-15-CD161115
# 32549  ParlaMint-ES_2016-11-15-CD161115
# 32550  ParlaMint-ES_2016-11-15-CD161115
#
#                                           id  \
# 0        ParlaMint-ES_2022-06-29-CD220629.u3
# 1        ParlaMint-ES_2022-06-29-CD220629.u5
# 2        ParlaMint-ES_2022-06-29-CD220629.u7
# 3        ParlaMint-ES_2022-06-29-CD220629.u9
# 4       ParlaMint-ES_2022-06-29-CD220629.u12
# ...                                      ...
# 32546  ParlaMint-ES_2016-11-15-CD161115.u120
# 32547  ParlaMint-ES_2016-11-15-CD161115.u122
# 32548  ParlaMint-ES_2016-11-15-CD161115.u124
# 32549  ParlaMint-ES_2016-11-15-CD161115.u126
# 32550  ParlaMint-ES_2016-11-15-CD161115.u129
#
#                                        title        date         body  \
# 0      Sesión plenaria núm. 191 (2022-06-29)  2022-06-29  Cámara Baja
# 1      Sesión plenaria núm. 191 (2022-06-29)  2022-06-29  Cámara Baja
# 2      Sesión plenaria núm. 191 (2022-06-29)  2022-06-29  Cámara Baja
# 3      Sesión plenaria núm. 191 (2022-06-29)  2022-06-29  Cámara Baja
# 4      Sesión plenaria núm. 191 (2022-06-29)  2022-06-29  Cámara Baja
# ...                                      ...         ...          ...
# 32546   Sesión plenaria núm. 14 (2016-11-15)  2016-11-15  Cámara Baja
# 32547   Sesión plenaria núm. 14 (2016-11-15)  2016-11-15  Cámara Baja
# 32548   Sesión plenaria núm. 14 (2016-11-15)  2016-11-15  Cámara Baja
# 32549   Sesión plenaria núm. 14 (2016-11-15)  2016-11-15  Cámara Baja
# 32550   Sesión plenaria núm. 14 (2016-11-15)  2016-11-15  Cámara Baja
#
#                   term                   session meeting     sitting agenda  \
# 0      Legislatura XIV  Sesión plenaria núm. 191       -  2022-06-29      -
# 1      Legislatura XIV  Sesión plenaria núm. 191       -  2022-06-29      -
# 2      Legislatura XIV  Sesión plenaria núm. 191       -  2022-06-29      -
# 3      Legislatura XIV  Sesión plenaria núm. 191       -  2022-06-29      -
# 4      Legislatura XIV  Sesión plenaria núm. 191       -  2022-06-29      -
# ...                ...                       ...     ...         ...    ...
# 32546  Legislatura XII   Sesión plenaria núm. 14       -  2016-11-15      -
# 32547  Legislatura XII   Sesión plenaria núm. 14       -  2016-11-15      -
# 32548  Legislatura XII   Sesión plenaria núm. 14       -  2016-11-15      -
# 32549  Legislatura XII   Sesión plenaria núm. 14       -  2016-11-15      -
# 32550  Legislatura XII   Sesión plenaria núm. 14       -  2016-11-15      -
#
#        ... party_status             party_orientation  \
# 0      ...   Opposition      Centro-derecha - Derecha
# 1      ...    Coalition              Centro-izquierda
# 2      ...   Opposition      Centro-derecha - Derecha
# 3      ...    Coalition              Centro-izquierda
# 4      ...   Opposition     Derecha - Extrema derecha
# ...    ...          ...                           ...
# 32546  ...   Opposition  Centro-izquierda - izquierda
# 32547  ...   Opposition  Centro-izquierda - izquierda
# 32548  ...   Opposition              Centro-izquierda
# 32549  ...   Opposition              Centro-izquierda
# 32550  ...    Coalition      Centro-derecha - Derecha
#
#                              speaker_id  \
# 0                      JaimeDeOlanoVela
# 1                NadiaCalviñoSantamaría
# 2                      JaimeDeOlanoVela
# 3                NadiaCalviñoSantamaría
# 4      IvánEspinosaDeLosMonterosDeSimón
# ...                                 ...
# 32546               GabrielRufiánRomero
# 32547               GabrielRufiánRomero
# 32548            MiguelÁngelHerediaDíaz
# 32549            MiguelÁngelHerediaDíaz
# 32550         AliciaSánchezCamachoPérez
#
#                                   speaker_name speaker_gender speaker_birth  \
# 0                         De Olano Vela, Jaime              M          1970
# 1                    Calviño Santamaría, Nadia              F          1968
# 2                         De Olano Vela, Jaime              M          1970
# 3                    Calviño Santamaría, Nadia              F          1968
# 4      Espinosa De Los Monteros De Simón, Iván              M          1971
# ...                                        ...            ...           ...
# 32546                   Rufián Romero, Gabriel              M          1982
# 32547                   Rufián Romero, Gabriel              M          1982
# 32548               Heredia Díaz, Miguel Ángel              M          1966
# 32549               Heredia Díaz, Miguel Ángel              M          1966
# 32550            Sánchez-Camacho Pérez, Alicia              F          1967
#
#       is_in_english                                    key  \
# 0             False    ParlaMint-ES_2022-06-29-CD220629.u3
# 1             False    ParlaMint-ES_2022-06-29-CD220629.u5
# 2             False    ParlaMint-ES_2022-06-29-CD220629.u7
# 3             False    ParlaMint-ES_2022-06-29-CD220629.u9
# 4             False   ParlaMint-ES_2022-06-29-CD220629.u12
# ...             ...                                    ...
# 32546         False  ParlaMint-ES_2016-11-15-CD161115.u120
# 32547         False  ParlaMint-ES_2016-11-15-CD161115.u122
# 32548         False  ParlaMint-ES_2016-11-15-CD161115.u124
# 32549         False  ParlaMint-ES_2016-11-15-CD161115.u126
# 32550         False  ParlaMint-ES_2016-11-15-CD161115.u129
#
#                                              speech_text  \
# 0      Gracias, presidenta. Señora Calviño, los dos ú...
# 1      Gracias, presidenta. Voy a responder a la preg...
# 2      Señora Calviño, menos mal que funcionan sus me...
# 3      Muchas gracias. Ya es mala suerte, señor Olano...
# 4      Gracias, señora presidenta. Señora vicepreside...
# ...                                                  ...
# 32546  Señora presidenta, por alusiones, quería conte...
# 32547  Es la falsedad que ha comentado el portavoz de...
# 32548  Señora presidenta, tengo un vídeo donde el señ...
# 32549  Evidentemente, no, pero le puedo enseñar el ví...
# 32550  Gracias, señora presidenta. Señorías, el pasad...
#
#                                 speech_text_preprocessed
# 0      gracias presidenta señora calviño dos último d...
# 1      gracias presidenta ir responder pregunta tener...
# 2      señora calviño menos mal funcionar medida infl...
# 3      gracia ser malo suerte señor olano poner usted...
# 4      gracias señora presidenta señora vicepresident...
# ...                                                  ...
# 32546  señora presidentar alusión querer contestar se...
# 32547  ser falsedad haber comentar portavoz grupo soc...
# 32548  señora presidenta tener vídeo señor rufián cua...
# 32549  evidentemente poder enseñar vídeo señora presi...
# 32550  gracias señora presidenta señorías pasado 30 o...
#
# [32551 rows x 27 columns]

# %% [markdown]
# # DATA PREPARATION

# %%
sel_cols = ['date', 'party_status', 'speaker_party', 'speaker_gender', 'speaker_id', 'speaker_name', 'speaker_birth', 'term', 'speech_text_preprocessed']

data = data[sel_cols]

# %%
power_definer(data)

# %%
list_of_interest_parties = ['PP', 'PSOE', 'UP', 'Vox', 'ERC-S', 'JxCat-Junts', 'EAJ-PNV', 'EH Bildu', 'CiU', 'ERC-CATSÍ']

data = data[data['speaker_party'].isin(list_of_interest_parties)]

podemos_vox = ['UP', 'Vox']
erc_junts = ['ERC-S', 'JxCat-Junts', 'CiU', 'ERC-CATSÍ']
bildu_pnv = ['EAJ-PNV', 'EH Bildu']
psoe_pp = ['PP', 'PSOE']

data_pv = data[data['speaker_party'].isin(podemos_vox)]
data_ej = data[data['speaker_party'].isin(erc_junts)]
data_bp = data[data['speaker_party'].isin(bildu_pnv)]
data = data[data['speaker_party'].isin(psoe_pp)]

display(data[['speaker_name', 'speaker_party']].head())
# Out:
#                 speaker_name speaker_party
# 0       De Olano Vela, Jaime            PP
# 1  Calviño Santamaría, Nadia          PSOE
# 2       De Olano Vela, Jaime            PP
# 3  Calviño Santamaría, Nadia          PSOE
# 5  Calviño Santamaría, Nadia          PSOE

# %%
data.loc[data['speaker_party'] == 'PSOE', 'speaker_party'] = 0
data.loc[data['speaker_party'] == 'PP', 'speaker_party'] = 1

display(data[['speaker_name', 'speaker_party']].head())
# Out:
#                 speaker_name speaker_party
# 0       De Olano Vela, Jaime             1
# 1  Calviño Santamaría, Nadia             0
# 2       De Olano Vela, Jaime             1
# 3  Calviño Santamaría, Nadia             0
# 5  Calviño Santamaría, Nadia             0

# %%
data_pv.loc[data_pv['speaker_party'] == 'UP', 'speaker_party'] = 0
data_pv.loc[data_pv['speaker_party'] == 'Vox', 'speaker_party'] = 1

data_ej.loc[data_ej['speaker_party'] == 'ERC-S', 'speaker_party'] = 0
data_ej.loc[data_ej['speaker_party'] == 'JxCat-Junts', 'speaker_party'] = 1
data_ej.loc[data_ej['speaker_party'] == 'CiU', 'speaker_party'] = 1
data_ej.loc[data_ej['speaker_party'] == 'ERC-CATSÍ', 'speaker_party'] = 0

data_bp.loc[data_bp['speaker_party'] == 'EH Bildu', 'speaker_party'] = 0
data_bp.loc[data_bp['speaker_party'] == 'EAJ-PNV', 'speaker_party'] = 1

# %%
print(data['speaker_party'].value_counts(), data_pv['speaker_party'].value_counts(), data_ej['speaker_party'].value_counts(), data_bp['speaker_party'].value_counts())
# Out:
# speaker_party
# 1    6358
# 0    6230
# Name: count, dtype: int64 speaker_party
# 0    2214
# 1    1888
# Name: count, dtype: int64 speaker_party
# 0    1700
# 1    1470
# Name: count, dtype: int64 speaker_party
# 1    1853
# 0     800
# Name: count, dtype: int64
